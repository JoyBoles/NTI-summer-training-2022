# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv('D:/NTI Artificial Intelligence/day 10/Breast_Cancer.csv')

# %%
df
# Out:
#       Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0      68  White        Married       T1      N1       IIA
# 1      50  White        Married       T2      N2      IIIA
# 2      58  White       Divorced       T3      N3      IIIC
# 3      58  White        Married       T1      N1       IIA
# 4      47  White        Married       T2      N1       IIB
# ...   ...    ...            ...      ...     ...       ...
# 4019   62  Other        Married       T1      N1       IIA
# 4020   56  White       Divorced       T2      N2      IIIA
# 4021   68  White        Married       T2      N1       IIB
# 4022   58  Black       Divorced       T2      N1       IIB
# 4023   46  White        Married       T2      N1       IIB
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0         Poorly differentiated     3  Regional           4        Positive
# 1     Moderately differentiated     2  Regional          35        Positive
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Visualization

# %% [markdown]
# ## Age

# %%
df['Age'].hist()
# Out:
# <AxesSubplot:>

# %%
df['Age'].min()
# Out:
# 30

# %%
df['Age'].max()
# Out:
# 69

# %%
labels=list(df['Age'].unique())
values=list(df['Age'].groupby(df['Age']).count())

# Create figure and subplots
fig, ax = plt.subplots()
plt.bar(labels, values)

#set figure size
f = plt.figure()
f.set_figwidth(50)
f.set_figheight(50)

# Set ticks i.e. locations of labels and values on x and y axces repectively
ax.set_xticks(np.arange(30,75,5))
ax.set_yticks(np.arange(0,200,25))

plt.show()

print(f'Age = {labels}')
print(f'count = {values}')
# Out:
# Age = [68, 50, 58, 47, 51, 40, 69, 46, 65, 48, 62, 61, 56, 43, 60, 57, 55, 63, 66, 53, 59, 54, 49, 64, 42, 37, 67, 31, 52, 33, 45, 38, 39, 36, 41, 44, 32, 34, 35, 30]
# count = [5, 14, 13, 15, 14, 20, 24, 28, 45, 52, 72, 71, 82, 92, 79, 102, 163, 161, 140, 162, 144, 148, 118, 155, 128, 154, 132, 144, 120, 147, 140, 143, 149, 153, 116, 122, 119, 119, 111, 108]

# %%
df['Age'].loc[df['Age']==50].count()
# Out:
# 144

# %%
df['Age'].loc[df['Age']==35].count()
# Out:
# 20

# %%
df['Age'].loc[df['Age']==30].count()
# Out:
# 5

# %%
df['Age'].loc[df['Age']==31].count()
# Out:
# 14

# %%
df['Age'].loc[df['Age']==32].count()
# Out:
# 13

# %%
df['Age'].loc[df['Age']==33].count()
# Out:
# 15

# %%
df['Age'].loc[df['Age']==69].count()
# Out:
# 108

# %% [markdown]
# ## Race

# %%
labels=list(df['Race'].unique())
values=list(df['Race'].groupby(df['Race']).count())

# Create figure and subplots
fig, ax = plt.subplots()
plt.bar(labels, values)

#set figure size
f = plt.figure()
f.set_figwidth(50)
f.set_figheight(50)

# Set ticks i.e. locations of labels and values on x and y axces repectively
#ax.set_xticks(np.arange(30,75,5)) #Note that we didn't set x-ticks because there are only 3 races white, black, and others
ax.set_yticks(np.arange(200,4000,500))

plt.show()

print(f'Race = {labels}')
print(f'count = {values}')
# Out:
# Race = ['White', 'Black', 'Other']
# count = [291, 320, 3413]

# %%
df['Race'].loc[df['Race']=='White'].count()
# Out:
# 3413

# %%
df['Race'].loc[df['Race']=='Black'].count()
# Out:
# 291

# %%
df['Race'].loc[df['Race']=='Other'].count()
# Out:
# 320

# %%
df['Race'].loc[df['Race']=='White']
# Out:
# 0       White
# 1       White
# 2       White
# 3       White
# 4       White
#         ...
# 4017    White
# 4018    White
# 4020    White
# 4021    White
# 4023    White
# Name: Race, Length: 3413, dtype: object

# %%
df['Race'].loc[df['Race']=='Black']
# Out:
# 18      Black
# 43      Black
# 52      Black
# 72      Black
# 108     Black
#         ...
# 3954    Black
# 3969    Black
# 3992    Black
# 4010    Black
# 4022    Black
# Name: Race, Length: 291, dtype: object

# %%
df['Race'].loc[df['Race']=='Other']
# Out:
# 20      Other
# 34      Other
# 39      Other
# 42      Other
# 60      Other
#         ...
# 3960    Other
# 3989    Other
# 3997    Other
# 4006    Other
# 4019    Other
# Name: Race, Length: 320, dtype: object

# %% [markdown]
# ## Marital Status

# %%
df['Marital Status'].unique()
# Out:
# array(['Married', 'Divorced', 'Single ', 'Widowed', 'Separated'],
#       dtype=object)

# %%
df['Marital Status'].loc[df['Marital Status']=='Married'].count()
# Out:
# 2643

# %%
df['Marital Status'].loc[df['Marital Status']=='Divorced'].count()
# Out:
# 486

# %%
df['Marital Status'].loc[df['Marital Status']=='Single '].count()
# Out:
# 615

# %%
df['Marital Status'].loc[df['Marital Status']=='Widowed'].count()
# Out:
# 235

# %%
df['Marital Status'].loc[df['Marital Status']=='Separated'].count()
# Out:
# 45

# %%
labels=list(df['Marital Status'].unique())
values=list(df['Marital Status'].groupby(df['Marital Status']).count())

# Create figure and subplots
fig, ax = plt.subplots()
plt.bar(labels, values)

#set figure size
f = plt.figure()
f.set_figwidth(50)
f.set_figheight(50)

# Set ticks i.e. locations of labels and values on x and y axces repectively
#ax.set_xticks(np.arange(30,75,5)) #Note that we didn't set x-ticks because there are only 3 races white, black, and others
ax.set_yticks(np.arange(0,3000,250))

plt.show()

print(f'Marital Status = {labels}')
print(f'count = {values}')
# Out:
# Marital Status = ['Married', 'Divorced', 'Single ', 'Widowed', 'Separated']
# count = [486, 2643, 45, 615, 235]

# %% [markdown]
# #### Unfortunately groupby() does not work in the same order as unique(), so the result is unordered
# #### We solve this problem by first identifying the unique values in the feature, then traversing over each value and get the count of it
# Correct answers are the following features only

# %% [markdown]
# ## T Stage

# %%
labels=list(df['T Stage '].unique())
print(labels)
# Out:
# ['T1', 'T2', 'T3', 'T4']

# %%
values=[]
for l in labels:
    values.append(df['T Stage '].loc[df['T Stage ']==l].count())
print(values)
# Out:
# [1603, 1786, 533, 102]

# %%
# Create figure and subplots
fig, ax = plt.subplots()
plt.bar(labels, values)

#set figure size
f = plt.figure()
f.set_figwidth(50)
f.set_figheight(50)

# Set ticks i.e. locations of labels and values on x and y axces repectively
#ax.set_xticks(np.arange(30,75,5)) #Note that we didn't set x-ticks because there are only 3 races white, black, and others
ax.set_yticks(np.arange(0,3000,250))

plt.show()

print(f'T Stage = {labels}')
print(f'count = {values}')
# Out:
# T Stage = ['T1', 'T2', 'T3', 'T4']
# count = [1603, 1786, 533, 102]

# %% [markdown]
# ## N Stage

# %%
labels=list(df['N Stage'].unique())
print(labels)
# Out:
# ['N1', 'N2', 'N3']

# %%
values=[]
for l in labels:
    values.append(df['N Stage'].loc[df['N Stage']==l].count())
print(values)
# Out:
# [2732, 820, 472]

# %%
# Create figure and subplots
fig, ax = plt.subplots()
plt.bar(labels, values)

#set figure size
f = plt.figure()
f.set_figwidth(50)
f.set_figheight(50)

# Set ticks i.e. locations of labels and values on x and y axces repectively
#ax.set_xticks(np.arange(30,75,5)) #Note that we didn't set x-ticks because there are only 3 races white, black, and others
ax.set_yticks(np.arange(0,3000,250))

plt.show()

print(f'N Stage = {labels}')
print(f'count = {values}')
# Out:
# N Stage = ['N1', 'N2', 'N3']
# count = [2732, 820, 472]

# %% [markdown]
# ## 6th Stage

# %%
labels=list(df['6th Stage'].unique())
print(labels)

values=[]
for l in labels:
    values.append(df['6th Stage'].loc[df['6th Stage']==l].count())
print(values)

# Create figure and subplots
fig, ax = plt.subplots()
plt.bar(labels, values)

#set figure size
f = plt.figure()
f.set_figwidth(50)
f.set_figheight(50)

# Set ticks i.e. locations of labels and values on x and y axces repectively
#ax.set_xticks(np.arange(30,75,5)) #Note that we didn't set x-ticks because there are only 3 races white, black, and others
ax.set_yticks(np.arange(0,1500,125))

plt.show()
# Out:
# ['IIA', 'IIIA', 'IIIC', 'IIB', 'IIIB']
# [1305, 1050, 472, 1130, 67]

# %%
df['6th Stage'].loc[df['6th Stage']=='IIA'].count()
# Out:
# 1305

# %%
df['6th Stage'].loc[df['6th Stage']=='IIIA'].count()
# Out:
# 1050

# %% [markdown]
# ## Differentiate

# %%
labels=list(df['differentiate'].unique())
print(labels)

values=[]
for l in labels:
    values.append(df['differentiate'].loc[df['differentiate']==l].count())
print(values)

# Create figure and subplots
fig, ax = plt.subplots()
plt.bar(labels, values, width=0.3)

#set figure size
"""
f = plt.figure()
f.set_figwidth(50)
f.set_figheight(50)
"""
plt.figure(figsize=(50,50))

# Set ticks i.e. locations of labels and values on x and y axces repectively
#ax.set_xticks(np.arange(30,75,5)) #Note that we didn't set x-ticks because there are only 3 races white, black, and others
ax.set_yticks(np.arange(0,3000,250))

plt.show()
# Out:
# ['Poorly differentiated', 'Moderately differentiated', 'Well differentiated', 'Undifferentiated']
# [1111, 2351, 543, 19]

# %% [markdown]
# ## Status (Output)

# %%
alive = df.loc[df['Status']=='Alive'].count()[0]
dead = df.loc[df['Status']=='Dead'].count()[0]

labels = ['Alive','Dead']
colors = ['red','#ababab']

plt.title('Alive Percentage',fontdict={'fontsize':20})

plt.pie([alive,dead], labels=labels, colors=colors, textprops={'fontsize': 14})

#plt.figure(figsize=(5,5), dpi=300)
fig = plt.gcf()
fig.set_size_inches(7,7)

plt.show()

# %% [markdown]
# ## Finding correlation

# %%
correlation=df.corr()
sb.heatmap(correlation, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# It seems there is a weak correlation between the features

# %% [markdown]
# # Data Cleansing

# %% [markdown]
# ## Checking for null values

# %%
df.isna().sum()
# Out:
# Age                       0
# Race                      0
# Marital Status            0
# T Stage                   0
# N Stage                   0
# 6th Stage                 0
# differentiate             0
# Grade                     0
# A Stage                   0
# Tumor Size                0
# Estrogen Status           0
# Progesterone Status       0
# Regional Node Examined    0
# Reginol Node Positive     0
# Survival Months           0
# Status                    0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# Obviously, the dataset contains no null values

# %% [markdown]
# Separating into features variables and target variable.

# %%
X=df.drop('Status',axis=1)
y=df['Status']
print(X)
print(type(X))
print("________________________________________________________________________")
print(y)
print(type(y))
# Out:
#       Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0      68  White        Married       T1      N1       IIA
# 1      50  White        Married       T2      N2      IIIA
# 2      58  White       Divorced       T3      N3      IIIC
# 3      58  White        Married       T1      N1       IIA
# 4      47  White        Married       T2      N1       IIB
# ...   ...    ...            ...      ...     ...       ...
# 4019   62  Other        Married       T1      N1       IIA
# 4020   56  White       Divorced       T2      N2      IIIA
# 4021   68  White        Married       T2      N1       IIB
# 4022   58  Black       Divorced       T2      N1       IIB
# 4023   46  White        Married       T2      N1       IIB
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0         Poorly differentiated     3  Regional           4        Positive
# 1     Moderately differentiated     2  Regional          35        Positive
# ...

# %%
sb.countplot(x=y)
# Out:
# <AxesSubplot:xlabel='Status', ylabel='count'>

# %% [markdown]
# ###### From pie chart and the count plot of the status, we need to perform resampling because data is extremely biased to alive

# %% [markdown]
# ### Using LabelEncoder to transform categorical variables into continuous variables.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder_race = LabelEncoder()
label_encoder_marital_status = LabelEncoder()
label_encoder_t_stage = LabelEncoder()
label_encoder_n_stage = LabelEncoder()
label_encoder_6th_stage = LabelEncoder()
label_encoder_differentiate = LabelEncoder()
label_encoder_grade = LabelEncoder()
label_encoder_a_stage = LabelEncoder()
label_encoder_estrogene = LabelEncoder()
label_encoder_progesterone = LabelEncoder()
label_encoder_status = LabelEncoder()

# %%
X.iloc[:,1] = label_encoder_race.fit_transform(X.iloc[:,1])
#print(X.iloc[:,1])
X.iloc[:,2] = label_encoder_marital_status.fit_transform(X.iloc[:,2])
X.iloc[:,3] = label_encoder_t_stage.fit_transform(X.iloc[:,3])
X.iloc[:,4] = label_encoder_n_stage.fit_transform(X.iloc[:,4])
X.iloc[:,5] = label_encoder_6th_stage.fit_transform(X.iloc[:,5])
X.iloc[:,6] = label_encoder_differentiate.fit_transform(X.iloc[:,6])
X.iloc[:,7] = label_encoder_grade.fit_transform(X.iloc[:,7])
X.iloc[:,8] = label_encoder_a_stage.fit_transform(X.iloc[:,8])
X.iloc[:,10] = label_encoder_estrogene.fit_transform(X.iloc[:,10])
X.iloc[:,11] = label_encoder_progesterone.fit_transform(X.iloc[:,11])

# %%
y = label_encoder_status.fit_transform(y)

# %% [markdown]
# ### RandomOverSampler

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
ros = RandomOverSampler(random_state=0) #creating a RandomOverSampler Object

# %%
X_over, y_over = ros.fit_resample(X, y) #This function duplicates random samples of the minority value of the feature to increase it and be equal to the majority value

# %%
sb.countplot(x=y_over) #This is a plot that count the occurance of a feature value
# Out:
# <AxesSubplot:xlabel='Status', ylabel='count'>

# %%
#y_over.loc['Status'=='Alive']
y_over.valuecount()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 #y_over.loc['Status'=='Alive']
# ----> 2 y_over.valuecount()
#
# NameError: name 'y_over' is not defined

# %% [markdown]
# ### SMOTE

# %%
from imblearn.over_sampling import SMOTE

# %%
smote=SMOTE(sampling_strategy='minority') #When str, specify the class targeted by the resampling. (it can be float, str, dict, or function)
#Here we specified only the minority class to be resampled

# %%
X_smote, y_smote = smote.fit_resample(X,y) #fit_resample() with SMOTE only accepts numerical data

# %%
sb.countplot(x=y_smote, tick_label=['Alive','Dead'])
# Out:
# <AxesSubplot:ylabel='count'>

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (2816, 15)
# (2816,)

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (1208, 15)
# (1208,)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lreg_model=LogisticRegression()

# %%
lreg_model.fit(X_train,y_train)
# Out:
# D:\python 3.10.6\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lreg_model.predict(X_test)
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
lreg_model.score(X_test,y_test)
# Out:
# 0.8940397350993378

# %% [markdown]
# #### Random Oversampled Data

# %%
X_train, X_test, y_train, y_test = train_test_split(X_over, y_over, test_size = 0.3, random_state = 0)

# %%
lreg_model=LogisticRegression()

# %%
X_train.iloc[:,1] = label_encoder_race.fit_transform(X_train.iloc[:,1])
#print(X.iloc[:,1])
X_train.iloc[:,2] = label_encoder_marital_status.fit_transform(X_train.iloc[:,2])
X_train.iloc[:,3] = label_encoder_t_stage.fit_transform(X_train.iloc[:,3])
X_train.iloc[:,4] = label_encoder_n_stage.fit_transform(X_train.iloc[:,4])
X_train.iloc[:,5] = label_encoder_6th_stage.fit_transform(X_train.iloc[:,5])
X_train.iloc[:,6] = label_encoder_differentiate.fit_transform(X_train.iloc[:,6])
X_train.iloc[:,7] = label_encoder_grade.fit_transform(X_train.iloc[:,7])
X_train.iloc[:,8] = label_encoder_a_stage.fit_transform(X_train.iloc[:,8])
X_train.iloc[:,10] = label_encoder_estrogene.fit_transform(X_train.iloc[:,10])
X_train.iloc[:,11] = label_encoder_progesterone.fit_transform(X_train.iloc[:,11])

# %%
lreg_model.fit(X_train,y_train)
# Out:
# D:\python 3.10.6\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_test.iloc[:,1] = label_encoder_race.fit_transform(X_test.iloc[:,1])
#print(X.iloc[:,1])
X_test.iloc[:,2] = label_encoder_marital_status.fit_transform(X_test.iloc[:,2])
X_test.iloc[:,3] = label_encoder_t_stage.fit_transform(X_test.iloc[:,3])
X_test.iloc[:,4] = label_encoder_n_stage.fit_transform(X_test.iloc[:,4])
X_test.iloc[:,5] = label_encoder_6th_stage.fit_transform(X_test.iloc[:,5])
X_test.iloc[:,6] = label_encoder_differentiate.fit_transform(X_test.iloc[:,6])
X_test.iloc[:,7] = label_encoder_grade.fit_transform(X_test.iloc[:,7])
X_test.iloc[:,8] = label_encoder_a_stage.fit_transform(X_test.iloc[:,8])
X_test.iloc[:,10] = label_encoder_estrogene.fit_transform(X_test.iloc[:,10])
X_test.iloc[:,11] = label_encoder_progesterone.fit_transform(X_test.iloc[:,11])

# %%
lreg_model.predict(X_test)
# Out:
# array(['Alive', 'Alive', 'Dead', ..., 'Dead', 'Dead', 'Dead'],
#       dtype=object)

# %%
lreg_model.score(X_test,y_test)
# Out:
# 0.7907090464547677

# %% [markdown]
# #### SMOTE Data

# %%
X_train, X_test, y_train, y_test = train_test_split(X_smote, y_smote, test_size = 0.3, random_state = 0)

# %%
lreg_model=LogisticRegression()

# %%
lreg_model.fit(X_train,y_train)
# Out:
# D:\python 3.10.6\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lreg_model.predict(X_test)
# Out:
# array([0, 0, 1, ..., 1, 1, 1])

# %%
lreg_model.score(X_test,y_test)
# Out:
# 0.7965770171149145

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
dt=DecisionTreeClassifier()

# %%
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt.score(X_test, y_test)
# Out:
# 0.8149068322981367

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_search={'criterion':['gini','entropy'], 'max_depth':[100,200,None], 'min_samples_split':[2,10,20], 'min_samples_leaf':[1,2,10]}
dt=DecisionTreeClassifier()
dt_gs=GridSearchCV(estimator=dt, param_grid=grid_search, cv=4, verbose=-1, n_jobs=-1)
dt_gs.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=4, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [100, 200, None],
#                          'min_samples_leaf': [1, 2, 10],
#                          'min_samples_split': [2, 10, 20]},
#              verbose=-1)

# %% [markdown]
# * cv: Determines the cross-validation splitting strategy.
# * verbose: controls the output, the higher the verbose the more detailed the output
# * n_jobs: number of jobs run by the processor in parallel, -1 means use all processors

# %%
dt_gs.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=100, min_samples_leaf=10, min_samples_split=10)

# %%
dt_gs.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 100,
#  'min_samples_leaf': 10,
#  'min_samples_split': 10}

# %%
pd.DataFrame(dt_gs.cv_results_).sort_values(by='rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 15       0.017107      0.003017         0.005544    7.312849e-03
# 7        0.019684      0.005019         0.003025    3.013561e-03
# 26       0.021372      0.014390         0.003517    4.120363e-03
# 24       0.023877      0.012665         0.004517    4.576123e-03
# 25       0.014242      0.000435         0.002748    4.320903e-04
# 16       0.014606      0.004574         0.005533    5.579412e-03
# 8        0.018616      0.000875         0.002139    2.008476e-04
# 6        0.013510      0.003999         0.002267    1.309290e-03
# 17       0.012581      0.003297         0.004531    3.591764e-03
# 5        0.018489      0.003277         0.002998    7.065500e-04
# 14       0.018115      0.003485         0.002017    3.494099e-03
# 23       0.017240      0.003343         0.002750    8.301927e-04
# 44       0.015241      0.000433         0.002999    1.976862e-07
# ...

# %%
dt_gs.score(X_test,y_test)
# Out:
# 0.8944099378881988

# %% [markdown]
# #### Random Oversampled Data

# %%
X_over.iloc[:,1] = label_encoder_race.fit_transform(X_over.iloc[:,1])
#print(X.iloc[:,1])
X_over.iloc[:,2] = label_encoder_marital_status.fit_transform(X_over.iloc[:,2])
X_over.iloc[:,3] = label_encoder_t_stage.fit_transform(X_over.iloc[:,3])
X_over.iloc[:,4] = label_encoder_n_stage.fit_transform(X_over.iloc[:,4])
X_over.iloc[:,5] = label_encoder_6th_stage.fit_transform(X_over.iloc[:,5])
X_over.iloc[:,6] = label_encoder_differentiate.fit_transform(X_over.iloc[:,6])
X_over.iloc[:,7] = label_encoder_grade.fit_transform(X_over.iloc[:,7])
X_over.iloc[:,8] = label_encoder_a_stage.fit_transform(X_over.iloc[:,8])
X_over.iloc[:,10] = label_encoder_estrogene.fit_transform(X_over.iloc[:,10])
X_over.iloc[:,11] = label_encoder_progesterone.fit_transform(X_over.iloc[:,11])

# %%
X_train, X_test, y_train, y_test = train_test_split(X_over, y_over, test_size = 0.2, random_state = 0)

# %%
dt_gs.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=4, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [100, 200, None],
#                          'min_samples_leaf': [1, 2, 10],
#                          'min_samples_split': [2, 10, 20]},
#              verbose=-1)

# %%
dt_gs.best_estimator_
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
dt_gs.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2}

# %%
pd.DataFrame(dt_gs.cv_results_).sort_values(by='rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 45       0.034258  7.428170e-03         0.003949        0.006840
# 27       0.031248  1.849666e-06         0.007812        0.007812
# 9        0.019531  6.765892e-03         0.011717        0.006765
# 36       0.029400  3.202452e-03         0.007739        0.007740
# 18       0.031247  6.419617e-07         0.003906        0.006766
# 0        0.028733  1.919705e-03         0.011742        0.009517
# 30       0.029726  6.152949e-03         0.005155        0.006380
# 48       0.031248  8.344650e-07         0.003906        0.006765
# 3        0.028173  8.147189e-03         0.007279        0.005576
# 39       0.034600  7.142219e-03         0.003651        0.006323
# 12       0.023436  7.813156e-03         0.007813        0.007813
# 21       0.019530  6.764413e-03         0.011718        0.006765
# 37       0.033233  3.437766e-03         0.000000        0.000000
# ...

# %%
dt_gs.score(X_test,y_test)
# Out:
# 0.9413489736070382

# %% [markdown]
# #### SMOTE Data

# %%
X_train, X_test, y_train, y_test = train_test_split(X_smote, y_smote, test_size = 0.2, random_state = 0)

# %%
dt_gs.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=4, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [100, 200, None],
#                          'min_samples_leaf': [1, 2, 10],
#                          'min_samples_split': [2, 10, 20]},
#              verbose=-1)

# %%
dt_gs.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=200)

# %%
dt_gs.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 200,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2}

# %%
pd.DataFrame(dt_gs.cv_results_).sort_values(by='rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 9        0.027342  6.765032e-03         0.000000        0.000000
# 18       0.027342  6.765342e-03         0.000000        0.000000
# 36       0.019530  6.764895e-03         0.007812        0.007812
# 45       0.031247  1.572479e-06         0.000000        0.000000
# 27       0.031248  9.684608e-07         0.000000        0.000000
# 0        0.025484  1.118380e-03         0.004248        0.002163
# 48       0.027342  6.765135e-03         0.000000        0.000000
# 21       0.027342  6.763724e-03         0.003906        0.006765
# 12       0.019529  6.765238e-03         0.003906        0.006766
# 39       0.026396  6.703352e-03         0.004866        0.006307
# 3        0.036727  6.256927e-03         0.003252        0.000830
# 30       0.031248  1.888630e-06         0.000000        0.000000
# 10       0.023435  7.811964e-03         0.000000        0.000000
# ...

# %%
dt_gs.score(X_test,y_test)
# Out:
# 0.8577712609970675

# %% [markdown]
# #### We notice that RandomOverSampler acheives best results with DecisionTreeClassifier

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier()
rf_gs=GridSearchCV(estimator=rf, param_grid=grid_search, cv=4, verbose=-1, n_jobs=-1)
rf_gs.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=4, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [100, 200, None],
#                          'min_samples_leaf': [1, 2, 10],
#                          'min_samples_split': [2, 10, 20]},
#              verbose=-1)

# %%
pd.DataFrame(rf_gs.cv_results_).sort_values(by='rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 20       0.454560      0.007909         0.037710        0.003288
# 19       0.475266      0.013087         0.037719        0.004361
# 13       0.465790      0.004122         0.040231        0.000011
# 28       0.579045      0.032307         0.039418        0.007330
# 26       0.427435      0.005033         0.035708        0.004581
# 3        0.480233      0.003290         0.043259        0.004141
# 27       0.556685      0.008110         0.037723        0.004355
# 49       0.546619      0.006008         0.047461        0.003934
# 14       0.458229      0.010586         0.039202        0.001013
# 2        0.456131      0.008097         0.042256        0.004724
# 8        0.427444      0.005221         0.040727        0.000857
# 0        0.518958      0.004017         0.043257        0.003007
# 4        0.465200      0.004357         0.039718        0.000881
# ...

# %%
rf_gs.score(X_test,y_test)
# Out:
# 0.9055900621118013

# %% [markdown]
# #### Random Oversampled Data

# %%
X_train, X_test, y_train, y_test = train_test_split(X_over, y_over, test_size = 0.2, random_state = 0)

# %%
rf_gs.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=4, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [100, 200, None],
#                          'min_samples_leaf': [1, 2, 10],
#                          'min_samples_split': [2, 10, 20]},
#              verbose=-1)

# %%
pd.DataFrame(rf_gs.cv_results_).sort_values(by='rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 45       0.813474  2.073752e-02         0.058336    1.429067e-02
# 0        0.706981  1.295481e-02         0.070101    4.970321e-03
# 18       0.687738  1.145720e-02         0.050778    6.765823e-03
# 36       0.757758  7.811666e-03         0.054685    7.811725e-03
# 9        0.695261  1.746792e-02         0.058591    6.765032e-03
# 27       0.757757  7.811308e-03         0.058590    6.765858e-03
# 30       0.714792  1.295454e-02         0.054683    7.811844e-03
# 39       0.754233  3.690817e-02         0.058151    4.690691e-03
# 48       0.825642  2.486266e-02         0.059764    7.577509e-03
# 21       0.718227  3.644238e-03         0.056656    8.463200e-03
# 3        0.667921  1.295636e-02         0.058590    6.765342e-03
# 12       0.714315  1.386413e-02         0.062495    1.044358e-06
# 37       0.718698  1.104719e-02         0.050778    6.765686e-03
# ...

# %%
dt_gs.score(X_test,y_test)
# Out:
# 0.9472140762463344

# %% [markdown]
# #### SMOTE Data

# %%
X_train, X_test, y_train, y_test = train_test_split(X_smote, y_smote, test_size = 0.2, random_state = 0)

# %%
rf_gs.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=4, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [100, 200, None],
#                          'min_samples_leaf': [1, 2, 10],
#                          'min_samples_split': [2, 10, 20]},
#              verbose=-1)

# %%
pd.DataFrame(rf_gs.cv_results_).sort_values(by='rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 27       0.900212      0.000831         0.054684    7.811308e-03
# 0        0.754188      0.013058         0.062497    1.071227e-06
# 18       0.836071      0.012407         0.052834    7.768700e-03
# 45       0.842511      0.013923         0.050777    6.765170e-03
# 9        0.835217      0.012396         0.059655    5.610353e-03
# 36       0.884764      0.008506         0.060417    5.226760e-03
# 39       0.833620      0.018811         0.059206    6.773235e-03
# 21       0.688280      0.006918         0.046872    1.057878e-06
# 48       0.765661      0.011178         0.046872    7.152557e-07
# 30       0.828038      0.008680         0.067461    6.903800e-03
# 10       0.721842      0.019155         0.057464    6.469405e-03
# 3        0.732006      0.012954         0.064883    1.179632e-02
# 37       0.872381      0.021521         0.059810    1.000303e-02
# ...

# %%
dt_gs.score(X_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File D:\python 3.10.6\lib\site-packages\sklearn\metrics\_classification.py:111, in _check_targets(y_true, y_pred)
#     110 try:
# --> 111     unique_values = np.union1d(y_true, y_pred)
#     112 except TypeError as e:
#     113     # We expect y_true and y_pred to be of the same data type.
#     114     # If `y_true` was provided to the classifier as strings,
#     115     # `y_pred` given by the classifier will also be encoded with
#     116     # strings. So we raise a meaningful error
#
# File <__array_function__ internals>:180, in union1d(*args, **kwargs)
#
# File D:\python 3.10.6\lib\site-packages\numpy\lib\arraysetops.py:781, in union1d(ar1, ar2)
#     749 """
#     750 Find the union of two arrays.
#     751
#    (...)
#     779 array([1, 2, 3, 4, 6])
#     780 """
# ...
